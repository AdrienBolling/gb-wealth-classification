# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df_districts = pd.read_csv('gb-districts.csv')
df_districts.head()
# Out:
#    Unnamed: 0 postal_code postal_code_trimmed     state postal_code_prefix  \
# 0           0        PH44                  PH  Scotland                 PH
# 1           1        LE13                  LE   England                 LE
# 2           2        LE14                  LE   England                 LE
# 3           3        WR11                  WR   England                 WR
# 4           4         BA8                  BA   England                 BA
#
#        uk_region postal_code_district
# 0       Scotland                Perth
# 1  East Midlands            Leicester
# 2  East Midlands            Leicester
# 3  West Midlands            Worcester
# 4     South West                 Bath

# %%
df_tax = pd.read_csv('../gb-tax-band-data.csv', encoding='latin-1')
df_tax.head()
# Out:
#   Geography1          Area Name Band   Bungalow       Flat   Terraced  \
# 0     ENGWAL  ENGLAND AND WALES  All  2,436,910  5,564,180  6,757,790
# 1     ENGWAL  ENGLAND AND WALES    A    342,430  2,193,790  2,288,430
# 2     ENGWAL  ENGLAND AND WALES    B    382,880  1,300,590  1,687,660
# 3     ENGWAL  ENGLAND AND WALES    C    647,190  1,123,910  1,415,450
# 4     ENGWAL  ENGLAND AND WALES    D    546,710    531,840    843,770
#
#   Semi-Detached   Detached
# 0     6,051,520  3,939,450
# 1       989,130     17,090
# 2     1,481,710     61,600
# 3     1,831,410    420,870
# 4     1,012,600    914,910

# %%
df_districts['uk_region'].unique()
# Out:
# array(['Scotland', 'East Midlands', 'West Midlands', 'South West',
#        'East of England', 'South East', 'North West', 'Wales',
#        'Greater London', 'East England', 'North East', 'Northern Ireland'],
#       dtype=object)

# %%
df_districts.loc[df_districts['postal_code_prefix'].isin(['DN','HD','HG','HU','HX','LS','S','WF','YO']), 'uk_region'] = 'Yorkshire and the Humber'

# %%
df_districts.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_districts
# Out:
#       postal_code postal_code_trimmed     state postal_code_prefix  \
# 0            PH44                  PH  Scotland                 PH
# 1            LE13                  LE   England                 LE
# 2            LE14                  LE   England                 LE
# 3            WR11                  WR   England                 WR
# 4             BA8                  BA   England                 BA
# ...           ...                 ...       ...                ...
# 43528        BA12                  BA   England                 BA
# 43529         BA9                  BA   England                 BA
# 43530         TR4                  TR   England                 TR
# 43531        TR26                  TR   England                 TR
# 43532        LE12                  LE   England                 LE
#
#            uk_region postal_code_district
# 0           Scotland                Perth
# 1      East Midlands            Leicester
# 2      East Midlands            Leicester
# 3      West Midlands            Worcester
# 4         South West                 Bath
# ...              ...                  ...
# 43528     South West                 Bath
# 43529     South West                 Bath
# 43530     South West                Truro
# 43531     South West                Truro
# 43532  East Midlands            Leicester
#
# [43533 rows x 6 columns]

# %%
df_districts['uk_region'].unique()
# Out:
# array(['Scotland', 'East Midlands', 'West Midlands', 'South West',
#        'East of England', 'South East', 'North West', 'Wales',
#        'Greater London', 'East England', 'Yorkshire and the Humber',
#        'North East', 'Northern Ireland'], dtype=object)

# %%
filter = df_tax['Geography1'] == 'REGL'

# %%
df_tax[filter]['Area Name'].unique()
# Out:
# array(['NORTH EAST', 'NORTH WEST', 'YORKSHIRE AND THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST'], dtype=object)

# %%
df_tax = df_tax[filter]

# %%
df_tax = df_tax.replace({'Area Name':{'NORTH EAST':'North East', 'NORTH WEST':'North West', 'YORKSHIRE AND THE HUMBER':'Yorkshire and the Humber', 'EAST MIDLANDS':'East Midlands', 'WEST MIDLANDS':'West Midlands','EAST':'East England', 'LONDON':'Greater London', 'SOUTH EAST':'South East', 'SOUTH WEST':'South West'}})

# %%
df_tax = df_tax.reset_index()

# %%
df_tax.drop(columns=['index', 'Geography1'], inplace=True)

# %%
df_tax
# Out:
#      Area Name Band Bungalow     Flat Terraced Semi-Detached Detached
# 0   North East  All  140,720  196,710  364,130       365,330  136,400
# 1   North East    A   58,850  162,100  276,110       158,280    1,570
# 2   North East    B   25,850   18,760   51,180        86,800    3,710
# 3   North East    C   27,970    9,730   21,490        90,210   28,220
# 4   North East    D   15,220    4,610    8,860        21,140   47,890
# ..         ...  ...      ...      ...      ...           ...      ...
# 76  South West    D   97,030   27,110   50,010        87,910  127,200
# 77  South West    E   52,300   11,580   19,010        26,010  148,850
# 78  South West    F   17,260    4,220    6,910         9,760   92,050
# 79  South West    G    5,030    2,090    3,050         4,500   58,930
# 80  South West    H      170      270      200           300    6,200
#
# [81 rows x 7 columns]

# %%
def col_strip(x):
    return x.replace(',', '')
for column in ['Bungalow','Flat','Terraced','Semi-Detached','Detached']:
    df_tax[column] = df_tax[column].apply(col_strip)
df_tax = df_tax.astype({'Area Name':'str', 'Band':'str', 'Bungalow':'int32', 'Flat':'int32', 'Terraced':'int32', 'Semi-Detached':'int32', 'Detached':'int32'})

# %%
def percentage(column):
   if column[0] == 0:
      return 0
   return (column/column[0])*100

# %%
regions_df = []
types = []
types = ['Bungalow', 'Flat', 'Terraced', 'Semi-Detached', 'Detached']
for area in df_tax['Area Name'].unique():
    temp = (df_tax.loc[df_tax['Area Name']==area]).copy(deep=True).reset_index(drop=True)
    regions_df.append(temp)

# %%
def sum(a,b,c,d,e):
    return (a+b+c+d+e)/5

def sum2(a,b,c,d):
    return (a+b+c+d)/4

# %%
for i in range(len(regions_df)):
    for type in types:
        (regions_df[i])[type+'_%'] = percentage((regions_df[i])[type])
    regions_df[i]['All_Band_%'] = sum(regions_df[i]['Flat_%'], regions_df[i]['Terraced_%'], regions_df[i]['Bungalow_%'], regions_df[i]['Semi-Detached_%'], regions_df[i]['Detached_%'])
    regions_df[i]['All_Band_%_except_Flats'] = sum2(regions_df[i]['Terraced_%'], regions_df[i]['Bungalow_%'], regions_df[i]['Semi-Detached_%'], regions_df[i]['Detached_%'])

# %%
final = pd.DataFrame(columns=regions_df[0].columns)
for df in regions_df:
    final = pd.concat([final,df], ignore_index=True)
cols = list(final)
for i in range(2,len(cols)):
    final = final.astype({cols[i]:'float64'})

# %%
final.dtypes
# Out:
# Area Name                   object
# Band                        object
# Bungalow                   float64
# Flat                       float64
# Terraced                   float64
# Semi-Detached              float64
# Detached                   float64
# Bungalow_%                 float64
# Flat_%                     float64
# Terraced_%                 float64
# Semi-Detached_%            float64
# Detached_%                 float64
# All_Band_%                 float64
# All_Band_%_except_Flats    float64
# dtype: object

# %%
def sum(a,b,c,d,e):
    return (a+b+c+d+e)/5

def sum2(a,b,c,d):
    return (a+b+c+d)/4

# %%
final['All_Band_%'] = sum(final['Flat_%'], final['Terraced_%'], final['Bungalow_%'], final['Semi-Detached_%'], final['Detached_%'])
final['All_Band_%_except_Flats'] = sum2(final['Terraced_%'], final['Bungalow_%'], final['Semi-Detached_%'], final['Detached_%'])
final
# Out:
#      Area Name Band  Bungalow      Flat  Terraced  Semi-Detached  Detached  \
# 0   North East  All  140720.0  196710.0  364130.0       365330.0  136400.0
# 1   North East    A   58850.0  162100.0  276110.0       158280.0    1570.0
# 2   North East    B   25850.0   18760.0   51180.0        86800.0    3710.0
# 3   North East    C   27970.0    9730.0   21490.0        90210.0   28220.0
# 4   North East    D   15220.0    4610.0    8860.0        21140.0   47890.0
# ..         ...  ...       ...       ...       ...            ...       ...
# 76  South West    D   97030.0   27110.0   50010.0        87910.0  127200.0
# 77  South West    E   52300.0   11580.0   19010.0        26010.0  148850.0
# 78  South West    F   17260.0    4220.0    6910.0         9760.0   92050.0
# 79  South West    G    5030.0    2090.0    3050.0         4500.0   58930.0
# 80  South West    H     170.0     270.0     200.0          300.0    6200.0
#
#     Bungalow_%      Flat_%  Terraced_%  Semi-Detached_%  Detached_%  \
# 0   100.000000  100.000000  100.000000       100.000000  100.000000
# 1    41.820637   82.405572   75.827314        43.325213    1.151026
# 2    18.369812    9.536882   14.055420        23.759341    2.719941
# 3    19.876350    4.946368    5.901738        24.692744   20.689150
# 4    10.815804    2.343551    2.433197         5.786549   35.109971
# ..         ...         ...         ...              ...         ...
# 76   29.714583    5.606568    8.030252        16.877856   26.443807
# 77   16.016415    2.394838    3.052491         4.993664   30.944659
# 78    5.285723    0.872730    1.109559         1.873824   19.136418
# 79    1.540393    0.432229    0.489747         0.863956   12.251050
# 80    0.052061    0.055838    0.032115         0.057597    1.288928
#
#     All_Band_%  All_Band_%_except_Flats
# 0   100.000000               100.000000
# 1    48.905952                40.531048
# 2    13.688279                14.726129
# 3    15.221270                17.789995
# 4    11.297815                13.536380
# ..         ...                      ...
# 76   17.334613                20.266624
# 77   11.480413                13.751807
# 78    5.655651                 6.851381
# 79    3.115475                 3.786287
# 80    0.297308                 0.357675
#
# [81 rows x 14 columns]

# %%
final.to_csv('gb-tax-band-information.csv')
